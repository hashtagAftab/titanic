# %%
import pandas as pd

# %%
train_data = pd.read_csv('train.csv')[['PassengerId', 'Name', 'Survived']]
test_data = pd.read_csv('test.csv')[['PassengerId', 'Name']]

# %%
train_data.head()
# Out:
#    PassengerId                                               Name  Survived
# 0            1                            Braund, Mr. Owen Harris         0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2            3                             Heikkinen, Miss. Laina         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4            5                           Allen, Mr. William Henry         0

# %%
test_data.head()
# Out:
#    PassengerId                                          Name
# 0          892                              Kelly, Mr. James
# 1          893              Wilkes, Mrs. James (Ellen Needs)
# 2          894                     Myles, Mr. Thomas Francis
# 3          895                              Wirz, Mr. Albert
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)

# %%
#Extracting Surname and Title from Name col.
train_data['Title'], test_data['Title'] = (df['Name'].apply(lambda x: x.split(',')[1]).apply(lambda x: x.split()[0]) for df in [train_data, test_data])
train_data['Surname'], test_data['Surname'] = (df['Name'].apply(lambda x: x.split(',')[0]) for df in [train_data, test_data])

# %%
data = train_data.append(test_data)
data.groupby('Title')['PassengerId'].count()
# Out:
# Title
# Capt.          1
# Col.           4
# Don.           1
# Dona.          1
# Dr.            8
# Jonkheer.      1
# Lady.          1
# Major.         2
# Master.       61
# Miss.        260
# Mlle.          2
# Mme.           1
# Mr.          757
# Mrs.         197
# Ms.            2
# Rev.           8
# Sir.           1
# the            1
# Name: PassengerId, dtype: int64

# %%
#We incorrectly extracted 'the' as a Title
data[data.Title=='the']
# Out:
#      PassengerId                                               Name  Survived  \
# 759          760  Rothes, the Countess. of (Lucy Noel Martha Dye...       1.0
#
#     Title Surname
# 759   the  Rothes

# %%
#Correcting the Title of PassengerId==760
train_data.loc[(train_data.PassengerId==760), 'Title'] = 'Countess.'
data.loc[(train_data.PassengerId==760), 'Title'] = 'Countess.'

# %%
#Creating a dictionary to map Title to relevant Category
TitleSexDict = {'Capt.': 'man', 'Don.': 'man', 'Major.': 'man', 'Col.': 'man', 'Rev.': 'man', 'Dr.': 'man', 'Sir.': 'man',
                'Mr.': 'man', 'Jonkheer': 'man', 'Dona.': 'woman', 'Countess.': 'woman', 'Mme.': 'woman', 'Mlle.': 'woman',
                'Ms.': 'woman', 'Miss.': 'woman', 'Lady.': 'woman', 'Mrs.': 'woman', 'Master.': 'boy'}

# %%
train_data['Category'], test_data['Category'], data['Category'] = (df.Title.map(TitleSexDict) for df in [train_data, test_data, data])

# %%
data.head()
# Out:
#    PassengerId                                               Name  Survived  \
# 0            1                            Braund, Mr. Owen Harris       0.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0
# 2            3                             Heikkinen, Miss. Laina       1.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0
# 4            5                           Allen, Mr. William Henry       0.0
#
#    Title    Surname Category
# 0    Mr.     Braund      man
# 1   Mrs.    Cumings    woman
# 2  Miss.  Heikkinen    woman
# 3   Mrs.   Futrelle    woman
# 4    Mr.      Allen      man

# %% [markdown]
# Now we have to identify woman-child-groups e.g., women and children with a common Surname. For that, we'll create a temporary dataset from combined data excluding men and then take the frequency of Surname in a dictionary.

# %%
temp = train_data[(train_data.Category!='man')]
temp.head()
# Out:
#    PassengerId                                               Name  Survived  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2            3                             Heikkinen, Miss. Laina         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 7            8                     Palsson, Master. Gosta Leonard         0
# 8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
#
#      Title    Surname Category
# 1     Mrs.    Cumings    woman
# 2    Miss.  Heikkinen    woman
# 3     Mrs.   Futrelle    woman
# 7  Master.    Palsson      boy
# 8     Mrs.    Johnson    woman

# %%
SurnameDict = temp.groupby('Surname')['PassengerId'].count().to_dict()
SurnameDict
# Out:
# {'Abbott': 1,
#  'Abelson': 1,
#  'Ahlin': 1,
#  'Aks': 1,
#  'Allen': 1,
#  'Allison': 3,
#  'Andersen-Jensen': 1,
#  'Andersson': 7,
#  'Andrews': 1,
#  'Angle': 1,
#  'Appleton': 1,
#  'Arnold-Franchi': 1,
#  'Asplund': 4,
#  'Astor': 1,
#  'Attalah': 1,
#  'Aubart': 1,
#  'Ayoub': 1,
#  'Backstrom': 1,
#  'Baclini': 4,
#  'Ball': 1,
#  'Barbara': 2,
#  'Barber': 1,
#  'Baxter': 1,
#  'Bazzani': 1,
#  'Beane': 1,
#  'Becker': 2,
#  'Beckwith': 1,
#  'Bidois': 1,
#  'Bishop': 1,
#  'Bissette': 1,
#  'Bonnell': 1,
#  'Boulos': 2,
#  'Bourke': 2,
#  'Bowerman': 1,
#  'Brown': 3,
#  'Burns': 1,
#  'Buss': 1,
#  'Bystrom': 1,
#  'Cacic': 1,
#  'Caldwell': 2,
#  'Cameron': 1,
#  'Canavan': 1,
#  'Caram': 1,
#  'Carr': 1,
#  'Carter': 4,
#  'Chambers': 1,
#  'Cherry': 1,
#  'Chibnall': 1,
#  'Christy': 1,
#  'Clarke': 1,
#  'Cleaver': 1,
#  'Collyer': 2,
#  'Compton': 1,
#  'Connolly': 1,
#  'Coutts': 2,
#  'Crosby': 1,
#  'Cumings': 1,
#  'Dahlberg': 1,
#  'Danbom': 1,
#  'Davies': 1,
#  'Davis': 1,
#  'Davison': 1,
#  'Dean': 1,
#  'Devaney': 1,
#  'Dick': 1,
#  'Dodge': 1,
#  'Doling': 2,
#  'Dowdell': 1,
#  'Drew': 1,
#  'Duff Gordon': 1,
#  'Duran y More': 1,
#  'Emanuel': 1,
#  'Endres': 1,
#  'Eustis': 1,
#  'Faunthorpe': 1,
#  'Fleming': 1,
#  'Ford': 3,
#  'Fortune': 2,
#  'Francatelli': 1,
#  'Frauenthal': 1,
#  'Frolicher': 1,
#  'Funk': 1,
#  'Futrelle': 1,
#  'Garside': 1,
#  'Gilnagh': 1,
#  'Glynn': 1,
#  'Goldenberg': 1,
#  'Goldsmith': 2,
#  'Goodwin': 5,
#  'Graham': 2,
#  'Haas': 1,
#  'Hakkarainen': 1,
#  'Hamalainen': 2,
#  'Harknett': 1,
#  'Harper': 2,
#  'Harris': 1,
#  'Hart': 2,
#  'Hays': 2,
#  'Healy': 1,
#  'Hegarty': 1,
#  'Heikkinen': 1,
#  'Heininen': 1,
#  'Henry': 1,
#  'Herman': 2,
#  'Hewlett': 1,
#  'Hippach': 2,
#  'Hirvonen': 1,
#  'Hocking': 1,
#  'Hogeboom': 1,
#  'Holverson': 1,
#  'Honkanen': 1,
#  'Hoyt': 1,
#  'Icard': 1,
#  'Ilett': 1,
#  'Ilmakangas': 1,
#  'Isham': 1,
#  'Jacobsohn': 1,
#  'Jermyn': 1,
#  'Jerwan': 1,
#  'Johnson': 3,
#  'Johnston': 1,
#  'Jussila': 2,
#  'Kantor': 1,
#  'Karun': 1,
#  'Keane': 1,
#  'Kelly': 3,
#  'Kenyon': 1,
#  'Kink-Heilmann': 1,
#  'Lahtinen': 1,
#  'Laitinen': 1,
#  'Landergren': 1,
#  'Laroche': 2,
#  'LeRoy': 1,
#  'Lefebre': 4,
#  'Lehmann': 1,
#  'Leitch': 1,
#  'Lemore': 1,
#  'Lindahl': 1,
#  'Lindblom': 1,
#  'Lines': 1,
#  'Lobb': 1,
#  'Longley': 1,
#  'Louch': 1,
#  'Lurette': 1,
#  'Mack': 1,
#  'Madigan': 1,
#  'Madill': 1,
#  'Maioni': 1,
#  'Mallet': 1,
#  'Mangan': 1,
#  'Mannion': 1,
#  'Masselmani': 1,
#  'Mayne': 1,
#  'McCoy': 1,
#  'McDermott': 1,
#  'McGovern': 1,
#  'McGowan': 1,
#  'Meanwell': 1,
#  'Meek': 1,
#  'Mellinger': 2,
#  'Meyer': 1,
#  'Minahan': 1,
#  'Mockler': 1,
#  'Moor': 2,
#  'Moran': 1,
#  'Moubarek': 2,
#  'Moussa': 1,
#  'Mullens': 1,
#  'Murphy': 2,
#  'Najib': 1,
#  'Nakid': 1,
#  'Nasser': 1,
#  'Navratil': 2,
#  'Newell': 2,
#  'Newsom': 1,
#  'Nicola-Yarred': 2,
#  'Nilsson': 1,
#  'Nye': 1,
#  'Nysten': 1,
#  "O'Brien": 1,
#  "O'Driscoll": 1,
#  "O'Dwyer": 1,
#  "O'Leary": 1,
#  "O'Sullivan": 1,
#  'Ohman': 1,
#  'Olsson': 1,
#  'Oreskovic': 1,
#  'Osman': 1,
#  'Palsson': 4,
#  'Panula': 4,
#  'Parrish': 1,
#  'Pears': 1,
#  'Penasco y Castellana': 1,
#  'Perreault': 1,
#  'Peter': 2,
#  'Peters': 1,
#  'Petranec': 1,
#  'Pettersson': 1,
#  'Phillips': 1,
#  'Pinsky': 1,
#  'Potter': 1,
#  'Quick': 2,
#  'Renouf': 1,
#  'Reuchlin': 1,
#  'Reynaldo': 1,
#  'Rice': 5,
#  'Richards': 3,
#  'Ridsdale': 1,
#  'Robert': 1,
#  'Robins': 1,
#  'Rosblom': 1,
#  'Rothes': 1,
#  'Rothschild': 1,
#  'Rugg': 1,
#  'Ryerson': 2,
#  'Sage': 4,
#  'Sagesser': 1,
#  'Salkjelsvik': 1,
#  'Sandstrom': 2,
#  'Serepeca': 1,
#  'Shelley': 1,
#  'Shutes': 1,
#  'Silven': 1,
#  'Silvey': 1,
#  'Sinkkonen': 1,
#  'Sjoblom': 1,
#  'Skoog': 5,
#  'Slayter': 1,
#  'Smith': 1,
#  'Spedden': 1,
#  'Spencer': 1,
#  'Stanley': 1,
#  'Stephenson': 1,
#  'Stone': 1,
#  'Strandberg': 1,
#  'Strom': 2,
#  'Swift': 1,
#  'Taussig': 2,
#  'Taylor': 1,
#  'Thayer': 1,
#  'Thomas': 1,
#  'Thorne': 1,
#  'Thorneycroft': 1,
#  'Toomey': 1,
#  'Touma': 1,
#  'Trout': 1,
#  'Troutt': 1,
#  'Turja': 1,
#  'Turkula': 1,
#  'Turpin': 1,
#  'Van Impe': 2,
#  'Vander Planke': 2,
#  'Vestrom': 1,
#  'Ward': 1,
#  'Warren': 1,
#  'Watt': 1,
#  'Webber': 1,
#  'Weisz': 1,
#  'Wells': 1,
#  'West': 2,
#  'Wick': 2,
#  'Yasbeck': 1,
#  'Young': 1,
#  'Yrois': 1,
#  'Zabour': 2,
#  'de Messemaeker': 1}

# %%
temp[(temp.Surname=='Allison')] #seems to work fine
# Out:
#      PassengerId                                             Name  Survived  \
# 297          298                     Allison, Miss. Helen Loraine         0
# 305          306                   Allison, Master. Hudson Trevor         1
# 498          499  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0
#
#        Title  Surname Category
# 297    Miss.  Allison    woman
# 305  Master.  Allison      boy
# 498     Mrs.  Allison    woman

# %%
temp['SurnameFreq'] = temp.Surname.map(SurnameDict)
# Out:
# C:\Users\alam\AppData\Local\Temp/ipykernel_11356/2549737909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['SurnameFreq'] = temp.Surname.map(SurnameDict)

# %%
temp.head()
# Out:
#    PassengerId                                               Name  Survived  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2            3                             Heikkinen, Miss. Laina         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 7            8                     Palsson, Master. Gosta Leonard         0
# 8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
#
#      Title    Surname Category  SurnameFreq
# 1     Mrs.    Cumings    woman            1
# 2    Miss.  Heikkinen    woman            1
# 3     Mrs.   Futrelle    woman            1
# 7  Master.    Palsson      boy            4
# 8     Mrs.    Johnson    woman            3

# %%
temp[(temp.Surname=='Palsson')]
# Out:
#      PassengerId                                         Name  Survived  \
# 7              8               Palsson, Master. Gosta Leonard         0
# 24            25                Palsson, Miss. Torborg Danira         0
# 374          375                   Palsson, Miss. Stina Viola         0
# 567          568  Palsson, Mrs. Nils (Alma Cornelia Berglund)         0
#
#        Title  Surname Category  SurnameFreq
# 7    Master.  Palsson      boy            4
# 24     Miss.  Palsson    woman            4
# 374    Miss.  Palsson    woman            4
# 567     Mrs.  Palsson    woman            4

# %%
train_data.loc[(train_data.Category!='man'), 'SurnameFreq'] = train_data.Surname.map(SurnameDict)

# %%
train_data.head()
# Out:
#    PassengerId                                               Name  Survived  \
# 0            1                            Braund, Mr. Owen Harris         0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2            3                             Heikkinen, Miss. Laina         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4            5                           Allen, Mr. William Henry         0
#
#    Title    Surname Category  SurnameFreq
# 0    Mr.     Braund      man          NaN
# 1   Mrs.    Cumings    woman          1.0
# 2  Miss.  Heikkinen    woman          1.0
# 3   Mrs.   Futrelle    woman          1.0
# 4    Mr.      Allen      man          NaN

# %%
train_data[train_data.Surname=='Allen'] #our neat little trick worked
# Out:
#      PassengerId                           Name  Survived  Title Surname  \
# 4              5       Allen, Mr. William Henry         0    Mr.   Allen
# 730          731  Allen, Miss. Elisabeth Walton         1  Miss.   Allen
#
#     Category  SurnameFreq
# 4        man          NaN
# 730    woman          1.0

# %% [markdown]
# We now have a count of Surname occuring in woman and male child passengers. We can deduce whether a passenger belonged to a woman-child-group or not based on whether or not SurnameFreq>1 or =1.

# %%
train_data.loc[(train_data.SurnameFreq>1), 'Group'] = 1

# %%
#The following 142 passengers belong to woman-child groups
train_data[(train_data.Group==1)]
# Out:
#      PassengerId                                               Name  Survived  \
# 7              8                     Palsson, Master. Gosta Leonard         0
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 10            11                    Sandstrom, Miss. Marguerite Rut         1
# 16            17                               Rice, Master. Eugene         0
# 18            19  Vander Planke, Mrs. Julius (Emelia Maria Vande...         0
# ..           ...                                                ...       ...
# 858          859              Baclini, Mrs. Solomon (Latifa Qurban)         1
# 863          864                  Sage, Miss. Dorothy Edith "Dolly"         0
# 869          870                    Johnson, Master. Harold Theodor         1
# 885          886               Rice, Mrs. William (Margaret Norton)         0
# 887          888                       Graham, Miss. Margaret Edith         1
#
#        Title        Surname Category  SurnameFreq  Group
# 7    Master.        Palsson      boy          4.0    1.0
# 8       Mrs.        Johnson    woman          3.0    1.0
# 10     Miss.      Sandstrom    woman          2.0    1.0
# 16   Master.           Rice      boy          5.0    1.0
# 18      Mrs.  Vander Planke    woman          2.0    1.0
# ..       ...            ...      ...          ...    ...
# 858     Mrs.        Baclini    woman          4.0    1.0
# 863    Miss.           Sage    woman          4.0    1.0
# 869  Master.        Johnson      boy          3.0    1.0
# 885     Mrs.           Rice    woman          5.0    1.0
# 887    Miss.         Graham    woman          2.0    1.0
#
# [142 rows x 8 columns]

# %%
temp = train_data[(train_data.Group==1)]

# %%
dic = temp.groupby('Surname')['Survived'].mean().to_dict()

# %%
print(dic)
# Out:
# {'Allison': 0.3333333333333333, 'Andersson': 0.14285714285714285, 'Asplund': 0.75, 'Baclini': 1.0, 'Barbara': 0.0, 'Becker': 1.0, 'Boulos': 0.0, 'Bourke': 0.0, 'Brown': 1.0, 'Caldwell': 1.0, 'Carter': 0.75, 'Collyer': 1.0, 'Coutts': 1.0, 'Doling': 1.0, 'Ford': 0.0, 'Fortune': 1.0, 'Goldsmith': 1.0, 'Goodwin': 0.0, 'Graham': 1.0, 'Hamalainen': 1.0, 'Harper': 1.0, 'Hart': 1.0, 'Hays': 1.0, 'Herman': 1.0, 'Hippach': 1.0, 'Johnson': 1.0, 'Jussila': 0.0, 'Kelly': 1.0, 'Laroche': 1.0, 'Lefebre': 0.0, 'Mellinger': 1.0, 'Moor': 1.0, 'Moubarek': 1.0, 'Murphy': 1.0, 'Navratil': 1.0, 'Newell': 1.0, 'Nicola-Yarred': 1.0, 'Palsson': 0.0, 'Panula': 0.0, 'Peter': 1.0, 'Quick': 1.0, 'Rice': 0.0, 'Richards': 1.0, 'Ryerson': 1.0, 'Sage': 0.0, 'Sandstrom': 1.0, 'Skoog': 0.0, 'Strom': 0.0, 'Taussig': 1.0, 'Van Impe': 0.0, 'Vander Planke': 0.0, 'West': 1.0, 'Wick': 1.0, 'Zabour': 0.0}

# %%
temp['SurnameSurvival'] = temp.Surname.map(dic)
# Out:
# C:\Users\alam\AppData\Local\Temp/ipykernel_11356/830383606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['SurnameSurvival'] = temp.Surname.map(dic)

# %%
temp
# Out:
#      PassengerId                                               Name  Survived  \
# 7              8                     Palsson, Master. Gosta Leonard         0
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 10            11                    Sandstrom, Miss. Marguerite Rut         1
# 16            17                               Rice, Master. Eugene         0
# 18            19  Vander Planke, Mrs. Julius (Emelia Maria Vande...         0
# ..           ...                                                ...       ...
# 858          859              Baclini, Mrs. Solomon (Latifa Qurban)         1
# 863          864                  Sage, Miss. Dorothy Edith "Dolly"         0
# 869          870                    Johnson, Master. Harold Theodor         1
# 885          886               Rice, Mrs. William (Margaret Norton)         0
# 887          888                       Graham, Miss. Margaret Edith         1
#
#        Title        Surname Category  SurnameFreq  Group  SurnameSurvival  \
# 7    Master.        Palsson      boy          4.0    1.0              0.0
# 8       Mrs.        Johnson    woman          3.0    1.0              1.0
# 10     Miss.      Sandstrom    woman          2.0    1.0              1.0
# 16   Master.           Rice      boy          5.0    1.0              0.0
# 18      Mrs.  Vander Planke    woman          2.0    1.0              0.0
# ..       ...            ...      ...          ...    ...              ...
# 858     Mrs.        Baclini    woman          4.0    1.0              1.0
# 863    Miss.           Sage    woman          4.0    1.0              0.0
# 869  Master.        Johnson      boy          3.0    1.0              1.0
# 885     Mrs.           Rice    woman          5.0    1.0              0.0
# 887    Miss.         Graham    woman          2.0    1.0              1.0
#
#      AdjustedSurvival  predict
# 7                 0.0      0.0
# 8                 1.0      1.0
# 10                1.0      1.0
# 16                0.0      0.0
# 18                0.0      0.0
# ..                ...      ...
# 858               1.0      1.0
# 863               0.0      0.0
# 869               1.0      1.0
# 885               0.0      0.0
# 887               1.0      1.0
#
# [142 rows x 11 columns]

# %%
survived = []
perished = []
mixed = []

for item in train_data['Surname']:
    if train_data[(train_data.Surname==item) & (train_data.Group==1)]['Survived'].mean() == 1 and item not in survived:
        survived.append(item)
    if train_data[(train_data.Surname==item) & (train_data.Group==1)]['Survived'].mean() == 0 and item not in perished:
        perished.append(item)
    if train_data[(train_data.Surname==item) & (train_data.Group==1)]['Survived'].mean() > 0 and train_data[(train_data.Surname==item) & (train_data.Group==1)]['Survived'].mean() < 1 and item not in mixed:
        mixed.append(item)
        
survived.sort()
perished.sort()
mixed.sort()

# %%
#These woman-child-groups all survived
print(survived)
# Out:
# ['Baclini', 'Becker', 'Brown', 'Caldwell', 'Collyer', 'Coutts', 'Doling', 'Fortune', 'Goldsmith', 'Graham', 'Hamalainen', 'Harper', 'Hart', 'Hays', 'Herman', 'Hippach', 'Johnson', 'Kelly', 'Laroche', 'Mellinger', 'Moor', 'Moubarek', 'Murphy', 'Navratil', 'Newell', 'Nicola-Yarred', 'Peter', 'Quick', 'Richards', 'Ryerson', 'Sandstrom', 'Taussig', 'West', 'Wick']

# %%
#These woman-child-groups all perished
print(perished)
# Out:
# ['Barbara', 'Boulos', 'Bourke', 'Ford', 'Goodwin', 'Jussila', 'Lefebre', 'Palsson', 'Panula', 'Rice', 'Sage', 'Skoog', 'Strom', 'Van Impe', 'Vander Planke', 'Zabour']

# %%
#These woman-child-groups had mixed survival
print(mixed)
# Out:
# ['Allison', 'Andersson', 'Asplund', 'Carter']

# %% [markdown]
# The above code shows that 124 out of 142 "woman-child-group" passengers were part of "woman-child-groups" that either entirely lived or died. And 18 out of the 142 were part of "woman-child-groups" with mixed survival. Among these 18 passengers, 14 lived or died according to their "woman-child-groups'" average fate and 4 did not. Therefore among all 142 "woman-child-group" passengers, 97.2% = 138/142 lived or died according to their "woman-child-groups'" average fate. Our new engineered feature is a near perfect predictor! Wow!

# %%
for item in survived:
    train_data.loc[(train_data.Surname==item) & (train_data.Group==1), 'SurnameSurvival'] = 1

# %%
for item in perished:
    train_data.loc[(train_data.Surname==item) & (train_data.Group==1), 'SurnameSurvival'] = 0

# %%
for item in mixed:
    train_data.loc[(train_data.Surname==item) & (train_data.Group==1), 'SurnameSurvival'] = train_data.loc[(train_data.Surname==item) & (train_data.Group==1)]['Survived'].mean()

# %% [markdown]
# Improvise AdjustedSurvival by rounding the figures

# %%
#Adjust survival rates for use on training dataset
train_data['AdjustedSurvival'] = (train_data.SurnameSurvival * train_data.SurnameFreq - train_data.Survived) / (train_data.SurnameFreq-1)
# apply gender model plus new predictor to training set
train_data.predict = 0
train_data.loc[(train_data.Category=='woman'), 'predict'] = 1
train_data.loc[(train_data.Category!='woman'), 'predict'] = 0
train_data.loc[(train_data.Category=='boy') & (train_data.AdjustedSurvival==1), 'predict'] = 1
train_data.loc[(train_data.Category=='woman') & (train_data.AdjustedSurvival==0), 'predict'] = 0

# %%
#predictions changed (from simple gender predictions) for 16 males
train_data[(train_data.Category=='boy')]['predict'].sum()
# Out:
# 16.0

# %%
#predictions changed for 36 females
sum(train_data[(train_data.Category=='woman')]['predict']==0)
# Out:
# 36

# %% [markdown]
# ### Predictions on test dataset

# %%
#I'll skip the cross-validation part
#By the way how does our test_data look so far
test_data.head()
# Out:
#    PassengerId                                          Name Title   Surname  \
# 0          892                              Kelly, Mr. James   Mr.     Kelly
# 1          893              Wilkes, Mrs. James (Ellen Needs)  Mrs.    Wilkes
# 2          894                     Myles, Mr. Thomas Francis   Mr.     Myles
# 3          895                              Wirz, Mr. Albert   Mr.      Wirz
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  Mrs.  Hirvonen
#
#   Category
# 0      man
# 1    woman
# 2      man
# 3      man
# 4    woman

# %%
#We've already extracted Title, Surname and Category in the test_data
combined_data = pd.concat([train_data, test_data], axis=0)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PassengerId       1309 non-null   int64
#  1   Name              1309 non-null   object
#  2   Survived          891 non-null    float64
#  3   Title             1309 non-null   object
#  4   Surname           1309 non-null   object
#  5   Category          1308 non-null   object
#  6   SurnameFreq       354 non-null    float64
#  7   Group             142 non-null    float64
#  8   SurnameSurvival   142 non-null    float64
#  9   AdjustedSurvival  142 non-null    float64
#  10  predict           891 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 122.7+ KB

# %%
#Ironically, there was a null value in Category in the training dataset
combined_data.loc[(combined_data.Category.isnull()), 'Category']='man'

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PassengerId       1309 non-null   int64
#  1   Name              1309 non-null   object
#  2   Survived          891 non-null    float64
#  3   Title             1309 non-null   object
#  4   Surname           1309 non-null   object
#  5   Category          1309 non-null   object
#  6   SurnameFreq       354 non-null    float64
#  7   Group             142 non-null    float64
#  8   SurnameSurvival   142 non-null    float64
#  9   AdjustedSurvival  142 non-null    float64
#  10  predict           891 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 122.7+ KB

# %%
# engineer 'woman-child-groups' for entire dataset
combined_data.SurnameFreq = None
combined_data.Group = None
combined_data.SurnameSurvival = None
combined_data.AdjustedSurvival = None

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PassengerId       1309 non-null   int64
#  1   Name              1309 non-null   object
#  2   Survived          891 non-null    float64
#  3   Title             1309 non-null   object
#  4   Surname           1309 non-null   object
#  5   Category          1309 non-null   object
#  6   SurnameFreq       0 non-null      object
#  7   Group             0 non-null      object
#  8   SurnameSurvival   0 non-null      object
#  9   AdjustedSurvival  0 non-null      object
#  10  predict           891 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 122.7+ KB

# %%
temp = combined_data[(combined_data.Category!='man')]
temp.head()
# Out:
#    PassengerId                                               Name  Survived  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0
# 2            3                             Heikkinen, Miss. Laina       1.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0
# 7            8                     Palsson, Master. Gosta Leonard       0.0
# 8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       1.0
#
#      Title    Surname Category SurnameFreq Group SurnameSurvival  \
# 1     Mrs.    Cumings    woman        None  None            None
# 2    Miss.  Heikkinen    woman        None  None            None
# 3     Mrs.   Futrelle    woman        None  None            None
# 7  Master.    Palsson      boy        None  None            None
# 8     Mrs.    Johnson    woman        None  None            None
#
#   AdjustedSurvival  predict
# 1             None      1.0
# 2             None      1.0
# 3             None      1.0
# 7             None      0.0
# 8             None      1.0

# %%
SurnameDict = temp.groupby('Surname')['PassengerId'].count().to_dict()
SurnameDict
# Out:
# {'Abbott': 2,
#  'Abelseth': 1,
#  'Abelson': 1,
#  'Abrahim': 1,
#  'Ahlin': 1,
#  'Aks': 2,
#  'Allen': 1,
#  'Allison': 3,
#  'Andersen-Jensen': 1,
#  'Andersson': 8,
#  'Andrews': 1,
#  'Angle': 1,
#  'Appleton': 1,
#  'Arnold-Franchi': 1,
#  'Asplund': 6,
#  'Assaf Khalil': 1,
#  'Astor': 1,
#  'Attalah': 1,
#  'Aubart': 1,
#  'Ayoub': 1,
#  'Backstrom': 1,
#  'Baclini': 4,
#  'Badman': 1,
#  'Ball': 1,
#  'Barbara': 2,
#  'Barber': 1,
#  'Barry': 1,
#  'Baxter': 1,
#  'Bazzani': 1,
#  'Beane': 1,
#  'Becker': 4,
#  'Beckwith': 1,
#  'Bentham': 1,
#  'Betros': 1,
#  'Bidois': 1,
#  'Bird': 1,
#  'Bishop': 1,
#  'Bissette': 1,
#  'Bonnell': 2,
#  'Boulos': 3,
#  'Bourke': 2,
#  'Bowen': 1,
#  'Bowerman': 1,
#  'Bradley': 1,
#  'Braf': 1,
#  'Brown': 5,
#  'Bryhl': 1,
#  'Buckley': 1,
#  'Bucknell': 1,
#  'Burns': 2,
#  'Buss': 1,
#  'Bystrom': 1,
#  'Cacic': 2,
#  'Caldwell': 2,
#  'Cameron': 1,
#  'Canavan': 1,
#  'Candee': 1,
#  'Caram': 1,
#  'Cardeza': 1,
#  'Carr': 2,
#  'Carter': 4,
#  'Cassebeer': 1,
#  'Cavendish': 1,
#  'Chaffee': 1,
#  'Chambers': 1,
#  'Chapman': 1,
#  'Chaudanson': 1,
#  'Cherry': 1,
#  'Chibnall': 1,
#  'Christy': 2,
#  'Clark': 1,
#  'Clarke': 1,
#  'Cleaver': 1,
#  'Collyer': 2,
#  'Compton': 2,
#  'Connolly': 2,
#  'Cook': 1,
#  'Corbett': 1,
#  'Corey': 1,
#  'Cornell': 1,
#  'Coutts': 3,
#  'Cribb': 1,
#  'Crosby': 2,
#  'Cumings': 1,
#  'Dahlberg': 1,
#  'Daly': 1,
#  'Danbom': 2,
#  'Daniels': 1,
#  'Davidson': 1,
#  'Davies': 2,
#  'Davis': 1,
#  'Davison': 1,
#  'Dean': 3,
#  'Devaney': 1,
#  'Dick': 1,
#  'Dodge': 2,
#  'Doling': 2,
#  'Douglas': 2,
#  'Dowdell': 1,
#  'Doyle': 1,
#  'Drapkin': 1,
#  'Drew': 2,
#  'Duff Gordon': 1,
#  'Duran y More': 2,
#  'Dyker': 1,
#  'Earnshaw': 1,
#  'Emanuel': 1,
#  'Endres': 1,
#  'Eustis': 1,
#  'Evans': 1,
#  'Faunthorpe': 1,
#  'Flegenheim': 1,
#  'Fleming': 2,
#  'Ford': 3,
#  'Fortune': 4,
#  'Francatelli': 1,
#  'Frauenthal': 1,
#  'Frolicher': 1,
#  'Frolicher-Stehli': 1,
#  'Funk': 1,
#  'Futrelle': 1,
#  'Garside': 1,
#  'Geiger': 1,
#  'Gibson': 2,
#  'Gilnagh': 1,
#  'Glynn': 1,
#  'Goldenberg': 1,
#  'Goldsmith': 2,
#  'Goodwin': 6,
#  'Graham': 2,
#  'Greenfield': 1,
#  'Haas': 1,
#  'Hagardon': 1,
#  'Hakkarainen': 1,
#  'Hamalainen': 2,
#  'Hansen': 1,
#  'Harder': 1,
#  'Harknett': 1,
#  'Harper': 2,
#  'Harris': 1,
#  'Hart': 2,
#  'Hays': 2,
#  'Healy': 1,
#  'Hegarty': 1,
#  'Heikkinen': 1,
#  'Heininen': 1,
#  'Hellstrom': 1,
#  'Henriksson': 1,
#  'Henry': 1,
#  'Herman': 3,
#  'Hewlett': 1,
#  'Hiltunen': 1,
#  'Hippach': 2,
#  'Hirvonen': 2,
#  'Hocking': 2,
#  'Hogeboom': 1,
#  'Hold': 1,
#  'Holverson': 1,
#  'Honkanen': 1,
#  'Howard': 2,
#  'Hoyt': 1,
#  'Icard': 1,
#  'Ilett': 1,
#  'Ilmakangas': 2,
#  'Isham': 1,
#  'Jacobsohn': 1,
#  'Jermyn': 1,
#  'Jerwan': 1,
#  'Johnson': 3,
#  'Johnston': 3,
#  'Jussila': 2,
#  'Kantor': 1,
#  'Karnes': 1,
#  'Karun': 1,
#  'Keane': 1,
#  'Kelly': 3,
#  'Kenyon': 1,
#  'Khalil': 1,
#  'Kimball': 1,
#  'Kink': 1,
#  'Kink-Heilmann': 2,
#  'Klasen': 2,
#  'Kreuchen': 1,
#  'Lahtinen': 1,
#  'Laitinen': 1,
#  'Landergren': 1,
#  'Laroche': 3,
#  'LeRoy': 1,
#  'Lefebre': 5,
#  'Lehmann': 1,
#  'Leitch': 1,
#  'Lemore': 1,
#  'Lennon': 1,
#  'Lindahl': 1,
#  'Lindblom': 1,
#  'Lindell': 1,
#  'Lindstrom': 1,
#  'Lines': 2,
#  'Lobb': 1,
#  'Longley': 1,
#  'Louch': 1,
#  'Lundin': 1,
#  'Lurette': 1,
#  'Mack': 1,
#  'Madigan': 1,
#  'Madill': 1,
#  'Mahon': 1,
#  'Maioni': 1,
#  'Mallet': 2,
#  'Mangan': 1,
#  'Mannion': 1,
#  'Marvin': 1,
#  'Masselmani': 1,
#  'Mayne': 1,
#  'McCarthy': 1,
#  'McCoy': 2,
#  'McDermott': 1,
#  'McGovern': 1,
#  'McGowan': 2,
#  'McNamee': 1,
#  'McNeill': 1,
#  'Meanwell': 1,
#  'Meek': 1,
#  'Mellinger': 2,
#  'Meyer': 1,
#  'Minahan': 2,
#  'Mockler': 1,
#  'Moor': 2,
#  'Moran': 1,
#  'Moubarek': 3,
#  'Moussa': 1,
#  'Mullens': 1,
#  'Mulvihill': 1,
#  'Murphy': 3,
#  'Najib': 1,
#  'Nakid': 2,
#  'Nasser': 1,
#  'Naughton': 1,
#  'Navratil': 2,
#  'Newell': 2,
#  'Newsom': 1,
#  'Nicola-Yarred': 2,
#  'Nieminen': 1,
#  'Nilsson': 2,
#  'Nye': 1,
#  'Nysten': 1,
#  "O'Brien": 1,
#  "O'Donoghue": 1,
#  "O'Driscoll": 1,
#  "O'Dwyer": 1,
#  "O'Leary": 1,
#  "O'Sullivan": 1,
#  'Ohman': 1,
#  'Oliva y Ocana': 1,
#  'Olsen': 1,
#  'Olsson': 1,
#  'Oreskovic': 2,
#  'Osman': 1,
#  'Ostby': 1,
#  'Palsson': 5,
#  'Panula': 4,
#  'Parrish': 1,
#  'Peacock': 3,
#  'Pears': 1,
#  'Penasco y Castellana': 1,
#  'Perreault': 1,
#  'Peter': 3,
#  'Peters': 1,
#  'Petranec': 1,
#  'Pettersson': 1,
#  'Phillips': 2,
#  'Pinsky': 1,
#  'Potter': 1,
#  'Quick': 3,
#  'Rasmussen': 1,
#  'Renouf': 1,
#  'Reynaldo': 1,
#  'Rice': 6,
#  'Richards': 3,
#  'Ridsdale': 1,
#  'Riihivouri': 1,
#  'Riordan': 1,
#  'Risien': 1,
#  'Robert': 1,
#  'Robins': 1,
#  'Rosblom': 2,
#  'Rosenbaum': 1,
#  'Roth': 1,
#  'Rothes': 1,
#  'Rothschild': 1,
#  'Rugg': 1,
#  'Ryerson': 4,
#  'Sage': 7,
#  'Sagesser': 1,
#  'Salkjelsvik': 1,
#  'Sandstrom': 3,
#  'Schabert': 1,
#  'Serepeca': 1,
#  'Shelley': 1,
#  'Shine': 1,
#  'Shutes': 1,
#  'Silven': 1,
#  'Silvey': 1,
#  'Sincock': 1,
#  'Sinkkonen': 1,
#  'Sjoblom': 1,
#  'Skoog': 5,
#  'Slayter': 1,
#  'Smith': 2,
#  'Smyth': 1,
#  'Snyder': 1,
#  'Spedden': 2,
#  'Spencer': 1,
#  'Stanley': 1,
#  'Stengel': 1,
#  'Stephenson': 1,
#  'Stone': 1,
#  'Strandberg': 1,
#  'Straus': 1,
#  'Strom': 2,
#  'Swift': 1,
#  'Taussig': 2,
#  'Taylor': 1,
#  'Thayer': 1,
#  'Thomas': 2,
#  'Thorne': 1,
#  'Thorneycroft': 1,
#  'Toomey': 1,
#  'Touma': 3,
#  'Trout': 1,
#  'Troutt': 1,
#  'Turja': 1,
#  'Turkula': 1,
#  'Turpin': 1,
#  'Van Impe': 2,
#  'Vander Planke': 2,
#  'Vestrom': 1,
#  'Walcroft': 1,
#  'Ward': 1,
#  'Ware': 1,
#  'Warren': 1,
#  'Watt': 2,
#  'Webber': 1,
#  'Weisz': 1,
#  'Wells': 3,
#  'West': 3,
#  'Whabee': 1,
#  'White': 1,
#  'Wick': 2,
#  'Widener': 1,
#  'Wilkes': 1,
#  'Willard': 1,
#  'Wilson': 1,
#  'Wright': 1,
#  'Yasbeck': 1,
#  'Young': 1,
#  'Yrois': 1,
#  'Zabour': 2,
#  'de Messemaeker': 1,
#  'del Carlo': 1,
#  'van Billiard': 2}

# %%
combined_data.reset_index(inplace=True)

# %%
combined_data.loc[(combined_data.Category!='man'), 'SurnameFreq'] = combined_data.Surname.map(SurnameDict)

# %%
combined_data.loc[(combined_data.SurnameFreq>1), 'Group'] = 1

# %%
#There are 263 woman-child-groups in the total dataset
combined_data[(combined_data.Group==1)]
# Out:
#       index  PassengerId                                               Name  \
# 7         7            8                     Palsson, Master. Gosta Leonard
# 8         8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10       10           11                    Sandstrom, Miss. Marguerite Rut
# 11       11           12                           Bonnell, Miss. Elizabeth
# 16       16           17                               Rice, Master. Eugene
# ...     ...          ...                                                ...
# 1291    400         1292                            Bonnell, Miss. Caroline
# 1293    402         1294                     Gibson, Miss. Dorothy Winifred
# 1300    409         1301                          Peacock, Miss. Treasteall
# 1302    411         1303    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1308    417         1309                           Peter, Master. Michael J
#
#       Survived    Title    Surname Category SurnameFreq Group SurnameSurvival  \
# 7          0.0  Master.    Palsson      boy         5.0     1            None
# 8          1.0     Mrs.    Johnson    woman         3.0     1            None
# 10         1.0    Miss.  Sandstrom    woman         3.0     1            None
# 11         1.0    Miss.    Bonnell    woman         2.0     1            None
# 16         0.0  Master.       Rice      boy         6.0     1            None
# ...        ...      ...        ...      ...         ...   ...             ...
# 1291       NaN    Miss.    Bonnell    woman         2.0     1            None
# 1293       NaN    Miss.     Gibson    woman         2.0     1            None
# 1300       NaN    Miss.    Peacock    woman         3.0     1            None
# 1302       NaN     Mrs.    Minahan    woman         2.0     1            None
# 1308       NaN  Master.      Peter      boy         3.0     1            None
#
#      AdjustedSurvival  predict
# 7                None      0.0
# 8                None      1.0
# 10               None      1.0
# 11               None      1.0
# 16               None      0.0
# ...               ...      ...
# 1291             None      NaN
# 1293             None      NaN
# 1300             None      NaN
# 1302             None      NaN
# 1308             None      NaN
#
# [263 rows x 12 columns]

# %%
combined_data[(combined_data.Surname=='Rice')]
# Out:
#      index  PassengerId                                  Name  Survived  \
# 16      16           17                  Rice, Master. Eugene       0.0
# 171    171          172                  Rice, Master. Arthur       0.0
# 278    278          279                    Rice, Master. Eric       0.0
# 787    787          788             Rice, Master. George Hugh       0.0
# 885    885          886  Rice, Mrs. William (Margaret Norton)       0.0
# 946     55          947                  Rice, Master. Albert       NaN
#
#        Title Surname Category SurnameFreq Group SurnameSurvival  \
# 16   Master.    Rice      boy         6.0     1            None
# 171  Master.    Rice      boy         6.0     1            None
# 278  Master.    Rice      boy         6.0     1            None
# 787  Master.    Rice      boy         6.0     1            None
# 885     Mrs.    Rice    woman         6.0     1            None
# 946  Master.    Rice      boy         6.0     1            None
#
#     AdjustedSurvival  predict
# 16              None      0.0
# 171             None      0.0
# 278             None      0.0
# 787             None      0.0
# 885             None      0.0
# 946             None      NaN

# %%
#Improvise by rounding the surname survival figures

# %%
for item in combined_data['Surname']:
    combined_data.loc[(combined_data.Surname==item) & (combined_data.Group==1), 'SurnameSurvival'] = train_data.loc[(train_data.Surname==item) & (train_data.Group==1)]['Survived'].mean()

# %%
combined_data[(combined_data.SurnameSurvival.isnull()==False)]
# Out:
#       index  PassengerId                                               Name  \
# 7         7            8                     Palsson, Master. Gosta Leonard
# 8         8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10       10           11                    Sandstrom, Miss. Marguerite Rut
# 16       16           17                               Rice, Master. Eugene
# 18       18           19  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# ...     ...          ...                                                ...
# 1256    365         1257                     Sage, Mrs. John (Annie Bullen)
# 1270    379         1271                        Asplund, Master. Carl Edgar
# 1276    385         1277                                 Herman, Miss. Kate
# 1280    389         1281                        Palsson, Master. Paul Folke
# 1308    417         1309                           Peter, Master. Michael J
#
#       Survived    Title        Surname Category SurnameFreq Group  \
# 7          0.0  Master.        Palsson      boy         5.0     1
# 8          1.0     Mrs.        Johnson    woman         3.0     1
# 10         1.0    Miss.      Sandstrom    woman         3.0     1
# 16         0.0  Master.           Rice      boy         6.0     1
# 18         0.0     Mrs.  Vander Planke    woman         2.0     1
# ...        ...      ...            ...      ...         ...   ...
# 1256       NaN     Mrs.           Sage    woman         7.0     1
# 1270       NaN  Master.        Asplund      boy         6.0     1
# 1276       NaN    Miss.         Herman    woman         3.0     1
# 1280       NaN  Master.        Palsson      boy         5.0     1
# 1308       NaN  Master.          Peter      boy         3.0     1
#
#      SurnameSurvival AdjustedSurvival  predict
# 7                0.0             None      0.0
# 8                1.0             None      1.0
# 10               1.0             None      1.0
# 16               0.0             None      0.0
# 18               0.0             None      0.0
# ...              ...              ...      ...
# 1256             0.0             None      NaN
# 1270            0.75             None      NaN
# 1276             1.0             None      NaN
# 1280             0.0             None      NaN
# 1308             1.0             None      NaN
#
# [170 rows x 12 columns]

# %%
#apply gender model plus new predictor to test dataset
combined_data.predict = 0
combined_data.loc[(combined_data.Category=='woman'), 'predict'] = 1
combined_data.loc[(combined_data.Category=='boy') & (combined_data.SurnameSurvival==1), 'predict'] = 1
combined_data.loc[(combined_data.Category=='woman') & (combined_data.SurnameSurvival==0), 'predict'] = 0

# %%
#Submitting to Kaggle
submission = combined_data[891:1309][['PassengerId', 'predict']]
submission.rename(columns = {'PassengerId': 'PassengerId', 'predict': 'Survived'}, inplace=True)
submission.to_csv('titanic_name.csv', index=False)
